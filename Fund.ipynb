# %% [markdown]
# # Solution 1

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import gzip
import wbdata

from urllib.request import urlopen
from xmltodict import parse
from zipfile import ZipFile
from io import BytesIO

# %%
DataBG = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="BG")
DataTUR = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="TUR")
DataIR = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="IR")
DataSY = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="SY")
DataGR = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="GR")
DataPL = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="PL")
DataRO = wbdata.get_dataframe({"SH.DYN.MORT":"Child Mortality Rate"}, country="RO")

# %%
#Turkey
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataTUR)
plt.xticks(range(0,len(DataBG),10))
plt.gca().invert_xaxis()
plt.title("Turkey")

#Bulgaria
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataBG)
plt.xticks(range(0,len(DataBG),10))
plt.gca().invert_xaxis()
plt.title("Bulgaria")

#Greece
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataBG)
plt.xticks(range(0,len(DataGR),10))
plt.gca().invert_xaxis()
plt.title("Grece")

#Syria
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataBG)
plt.xticks(range(0,len(DataSY),10))
plt.gca().invert_xaxis()
plt.title("Syria")

#Iran
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataBG)
plt.xticks(range(0,len(DataIR),10))
plt.gca().invert_xaxis()
plt.title("Iran")

#Poland
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataBG)
plt.xticks(range(0,len(DataPL),10))
plt.gca().invert_xaxis()
plt.title("Poland")

#Romania 
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataRO)
plt.xticks(range(0,len(DataBG),10))
plt.gca().invert_xaxis()
plt.title("Romania")
# Out:
# Text(0.5, 1.0, 'Romania')

# %%
DataTUR_Gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="TUR")
DataBG_gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="BG")
DataSY_gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="SY")
DataIR_gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="IR")
DataPL_gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="PL")
DataGR_gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="GR")
DataRO_gini = wbdata.get_dataframe({"SI.POV.GINI":"Gini Index"}, country="RO")

# %%
#Turkey
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataTUR_Gini)
plt.xticks(range(0,len(DataTUR_Gini),10))
plt.gca().invert_xaxis()
plt.title("Turkey")

#Bulgaria
plt.figure(figsize=(20,15))
plt.subplot(3,2,2)
plt.plot(DataBG_gini)
plt.xticks(range(0,len(DataBG_gini),10))
plt.gca().invert_xaxis()
plt.title("Bulgaria")

#Syria
plt.figure(figsize=(20,15))
plt.subplot(3,2,3)
plt.plot(DataSY_gini)
plt.xticks(range(0,len(DataSY_gini),10))
plt.gca().invert_xaxis()
plt.title("Syria")

#Greece
plt.figure(figsize=(20,15))
plt.subplot(3,2,4)
plt.plot(DataGR_gini)
plt.xticks(range(0,len(DataGR_gini),10))
plt.gca().invert_xaxis()
plt.title("Greece")

#Poland
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataPL_gini)
plt.xticks(range(0,len(DataPL_gini),10))
plt.gca().invert_xaxis()
plt.title("Poland")

#Iran
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataIR_gini)
plt.xticks(range(0,len(DataIR_gini),10))
plt.gca().invert_xaxis()
plt.title("Iran")
# Out:
# Text(0.5, 1.0, 'Iran')

# %%
DataTUR_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="TUR")
DataBG_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="BG")
DataPL_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="PL")
DataIR_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="IR")
DataGR_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="GR")
DataRO_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="RO")
DataSY_lit = wbdata.get_dataframe({"SE.ADT.LITR.FE.ZS":"Literacy of Woman"}, country="SY")

# %%
#Turkey
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataTUR_lit,"*")
plt.xticks(range(0,len(DataTUR_lit),10))
plt.gca().invert_xaxis()
plt.title("Turkey")

#Bulgaria
plt.figure(figsize=(20,15))
plt.subplot(3,2,2)
plt.plot(DataBG_lit,"*")
plt.xticks(range(0,len(DataBG_lit),10))
plt.gca().invert_xaxis()
plt.title("Bulgaria")

#Syria
plt.figure(figsize=(20,15))
plt.subplot(3,2,3)
plt.plot(DataSY_lit,"*")
plt.xticks(range(0,len(DataSY_lit),10))
plt.gca().invert_xaxis()
plt.title("Syria")

#Greece
plt.figure(figsize=(20,15))
plt.subplot(3,2,4)
plt.plot(DataGR_lit,"*")
plt.xticks(range(0,len(DataGR_lit),10))
plt.gca().invert_xaxis()
plt.title("Greece")

#Poland
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataPL_gini,"*")
plt.xticks(range(0,len(DataPL_gini),10))
plt.gca().invert_xaxis()
plt.title("Poland")

#Iran
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataIR_lit,"*")
plt.xticks(range(0,len(DataIR_lit),10))
plt.gca().invert_xaxis()
plt.title("Iran")


#Romania
plt.figure(figsize=(20,15))
plt.subplot(3,2,1)
plt.plot(DataRO_lit,"*")
plt.xticks(range(0,len(DataRO_lit),10))
plt.gca().invert_xaxis()
plt.title("Romania")
# Out:
# Text(0.5, 1.0, 'Romania')

# %%
plt.figure(figsize=(16,8)) 
plt.plot(DataTUR_lit,"*")
plt.plot(DataTUR)
plt.xticks(range(0,len(DataRO_lit),10))
plt.gca().invert_xaxis()
plt.title("Female Literacy - Child Mortality ")
# Out:
# Text(0.5, 1.0, 'Female Literacy - Child Mortality ')

# %% [markdown]
# I see no corellation.

# %%
plt.figure(figsize=(16,8)) 
plt.plot(DataTUR_lit,"*")
plt.plot(DataTUR_Gini)
plt.xticks(range(0,len(DataTUR_lit),10))
plt.gca().invert_xaxis()
plt.title("Female Literacy - Gini Index ")
# Out:
# Text(0.5, 1.0, 'Female Literacy - Gini Index ')

# %% [markdown]
# I see no corellation.

# %%
plt.figure(figsize=(16,8)) 
plt.plot(DataTUR)
plt.plot(DataTUR_Gini)
plt.xticks(range(0,len(DataTUR),10))
plt.gca().invert_xaxis()
plt.title("Cild Mortality - Gini Index ")
# Out:
# Text(0.5, 1.0, 'Cild Mortality - Gini Index ')

# %% [markdown]
# I see no corellation.
