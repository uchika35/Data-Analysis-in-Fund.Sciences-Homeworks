# %% [markdown]
# # Question 1
#
# For this question use the World Bank Data for Turkey for the following indicators. Use [wbgapi](https://pypi.org/project/wbgapi/) for getting the data.
#
# * [Literacy rate, adult female (SE.ADT.LITR.FE.ZS)](https://data.worldbank.org/indicator/SE.ADT.LITR.FE.ZS)
# * [Labor force, female (SL.TLF.TOTL.FE.ZS)](https://data.worldbank.org/indicator/SL.TLF.TOTL.FE.ZS)
# * [Poverty headcount ratio at national poverty lines (SI.POV.NAHC)](https://data.worldbank.org/indicator/SI.POV.NAHC)
# * [Current health expenditure per capita (SH.XPD.CHEX.PC.CD)](https://data.worldbank.org/indicator/SH.XPD.CHEX.PC.CD)
# * [GDP per capita (NY.GDP.PCAP.CD)](https://data.worldbank.org/indicator/NY.GDP.PCAP.CD)
# * [Mortality rate, under-5 (SH.DYN.MORT)](https://data.worldbank.org/indicator/SH.DYN.MORT)
#
#
# Using the [statsmodels](https://www.statsmodels.org/stable/index.html) library write the best linear regression model using child mortality as the dependent variable while the rest are considered as independent variables. Pay particular attention to the fact that the order of the variables put into the model significantly impacts the performance of the model. Choose the best model by considering
#
# * with the minimum number of variables and their interactions,
# * with the optimal ordering of the independent variables and their interactions,
# * $R^2$-score of the model,
# * statistical significance of the model coefficients,
# * ANOVA analysis of the model.

# %%
pip install wbgapi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wbgapi
#   Downloading wbgapi-1.0.12-py3-none-any.whl (36 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wbgapi) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from wbgapi) (2.23.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from wbgapi) (0.8.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->wbgapi) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->wbgapi) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->wbgapi) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->wbgapi) (3.0.4)
# Installing collected packages: wbgapi
# Successfully installed wbgapi-1.0.12

# %%
import pandas as pd
import wbgapi as wb
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

# %%
def pull_data(indicator):
    #return pd.DataFrame(list(wb.data.fetch(indicator)))
    return wb.data.DataFrame(indicator, "TUR").T

indicators = { "literacy_rate" : 'SE.ADT.LITR.FE.ZS',
                "labor_force" : 'SL.TLF.TOTL.FE.ZS',
                "poverty_hc_ratio" : 'SI.POV.NAHC',
                "c_health_exp" : 'SH.XPD.CHEX.PC.CD',
                "gdp" : 'NY.GDP.PCAP.CD',
                "mortality_rate" : 'SH.DYN.MORT'              
                }
df = pull_data(indicators.values())

# %% [markdown]
# This is a function of a friend of mine. I have done the same thing with brute force. I like the function and copied from him. I simply

# %%
df = df.ffill().fillna(0)

# %%
df = df.rename(columns ={"NY.GDP.PCAP.CD": "GDP", "SL.TLF.TOTL.FE.ZS": "labor_force" ,"SI.POV.NAHC" : "pov_headcount", "SH.XPD.CHEX.PC.CD":"health_exp" , "SH.DYN.MORT":"mortality_rate","SE.ADT.LITR.FE.ZS":"literacy_rate" })
df
# Out:
# series           GDP  literacy_rate  mortality_rate  health_exp  \
# YR1960    509.005545       0.000000           257.0    0.000000
# YR1961    283.828284       0.000000           249.3    0.000000
# YR1962    309.446624       0.000000           241.4    0.000000
# YR1963    350.662985       0.000000           233.5    0.000000
# YR1964    369.583469       0.000000           225.7    0.000000
# ...              ...            ...             ...         ...
# YR2017  10589.667725      93.498268            11.4  442.617615
# YR2018   9454.348443      93.498268            10.7  389.865570
# YR2019   9121.515167      94.424042            10.1  396.466827
# YR2020   8536.433320      94.424042             9.5  396.466827
# YR2021   9586.612450      94.424042             9.5  396.466827
#
# series  pov_headcount  labor_force
# YR1960            0.0     0.000000
# YR1961            0.0     0.000000
# YR1962            0.0     0.000000
# YR1963            0.0     0.000000
# YR1964            0.0     0.000000
# ...               ...          ...
# YR2017           13.9    32.799757
# YR2018           14.4    33.089766
# YR2019           15.0    33.360649
# YR2020           15.0    32.175606
# YR2021           15.0    32.470214
#
# [62 rows x 6 columns]

# %% [markdown]
# I chose a significance level 90% for my data

# %%
from statsmodels.formula.api import ols

# %%
X = df[['GDP', 'labor_force','health_exp', 'pov_headcount','pov_headcount' ]]
Y = df['mortality_rate']
XX = sm.add_constant(X)
model = sm.OLS(Y, XX)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         mortality_rate   R-squared:                       0.831
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     69.84
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):           2.63e-21
# Time:                        16:27:14   Log-Likelihood:                -301.66
# No. Observations:                  62   AIC:                             613.3
# Df Residuals:                      57   BIC:                             624.0
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const           191.5236      8.629     22.194      0.000     174.243     208.804
# GDP              -0.0301      0.006     -4.758      0.000      -0.043      -0.017
# labor_force      -1.4556      0.596     -2.444      0.018      -2.648      -0.263
# health_exp        0.4910      0.121      4.049      0.000       0.248       0.734
# pov_headcount    -1.8487      0.556     -3.327      0.002      -2.962      -0.736
# pov_headcount    -1.8487      0.556     -3.327      0.002      -2.962      -0.736
# ==============================================================================
# Omnibus:                        0.540   Durbin-Watson:                   0.460
# Prob(Omnibus):                  0.763   Jarque-Bera (JB):                0.129
# Skew:                          -0.061   Prob(JB):                        0.938
# Kurtosis:                       3.187   Cond. No.                     1.17e+19
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.49e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# R-squared value is less than 90% So I try another one which is variables and their interactions.

# %% [markdown]
# *This* model is not exactly what we want. I only can say that from R-squared. It it not too low but less than we want (>90%).

# %%
model = ols('mortality_rate ~ GDP	* literacy_rate *	health_exp * pov_headcount * labor_force', data=df).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         mortality_rate   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.933
# Method:                 Least Squares   F-statistic:                     32.41
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):           2.77e-17
# Time:                        16:30:26   Log-Likelihood:                -254.82
# No. Observations:                  62   AIC:                             565.6
# Df Residuals:                      34   BIC:                             625.2
# Df Model:                          27
# Covariance Type:            nonrobust
# ==========================================================================================================================
#                                                              coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------------
# Intercept                                                232.1276     12.866     18.042      0.000     205.981     258.274
# GDP                                                       -0.0465      0.023     -2.010      0.052      -0.093       0.001
# literacy_rate                                             -1.2530      0.593     -2.112      0.042      -2.459      -0.047
# GDP:literacy_rate                                          0.0002      0.000      0.500      0.620      -0.001       0.001
# health_exp                                                 0.0381      0.762      0.050      0.960      -1.511       1.588
# GDP:health_exp                                            -0.0017      0.085     -0.020      0.984      -0.174       0.171
# literacy_rate:health_exp                                  -0.0372      1.363     -0.027      0.978      -2.807       2.732
# GDP:literacy_rate:health_exp                            1.994e-05      0.001      0.025      0.980      -0.002       0.002
# pov_headcount                                              0.0374      1.504      0.025      0.980      -3.020       3.095
# GDP:pov_headcount                                          0.0116      1.234      0.009      0.993      -2.496       2.519
# literacy_rate:pov_headcount                               -1.2602     22.749     -0.055      0.956     -47.492      44.972
# GDP:literacy_rate:pov_headcount                            0.0001      0.013      0.009      0.992      -0.026       0.026
# health_exp:pov_headcount                                   0.9883     24.585      0.040      0.968     -48.973      50.950
# GDP:health_exp:pov_headcount                            -2.05e-05      0.005     -0.004      0.997      -0.010       0.010
# literacy_rate:health_exp:pov_headcount                    -0.0085      0.136     -0.063      0.950      -0.284       0.267
# GDP:literacy_rate:health_exp:pov_headcount             -9.374e-08    4.2e-05     -0.002      0.998   -8.55e-05    8.53e-05
# labor_force                                                0.0972      3.310      0.029      0.977      -6.631       6.825
# GDP:labor_force                                           -0.0008      0.302     -0.003      0.998      -0.615       0.614
# literacy_rate:labor_force                                 -0.0277      0.055     -0.502      0.619      -0.140       0.084
# GDP:literacy_rate:labor_force                           2.055e-05      0.004      0.005      0.996      -0.009       0.009
# health_exp:labor_force                                    -0.0396      3.740     -0.011      0.992      -7.641       7.562
# GDP:health_exp:labor_force                              7.637e-05      0.004      0.020      0.984      -0.008       0.008
# literacy_rate:health_exp:labor_force                       0.0017      0.086      0.020      0.984      -0.172       0.176
# GDP:literacy_rate:health_exp:labor_force               -8.889e-07   3.85e-05     -0.023      0.982   -7.92e-05    7.74e-05
# pov_headcount:labor_force                                  1.3510     45.285      0.030      0.976     -90.678      93.380
# GDP:pov_headcount:labor_force                             -0.0010      0.034     -0.030      0.976      -0.070       0.068
# literacy_rate:pov_headcount:labor_force                    0.0233      0.377      0.062      0.951      -0.742       0.788
# GDP:literacy_rate:pov_headcount:labor_force             2.862e-06      0.000      0.011      0.991      -0.001       0.001
# health_exp:pov_headcount:labor_force                      -0.0234      1.051     -0.022      0.982      -2.158       2.112
# GDP:health_exp:pov_headcount:labor_force                6.297e-08      0.000      0.000      1.000      -0.000       0.000
# literacy_rate:health_exp:pov_headcount:labor_force         0.0002      0.006      0.030      0.976      -0.012       0.012
# GDP:literacy_rate:health_exp:pov_headcount:labor_force  1.034e-08   2.28e-06      0.005      0.996   -4.62e-06    4.64e-06
# ==============================================================================
# Omnibus:                        6.450   Durbin-Watson:                   0.387
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                6.265
# Skew:                           0.500   Prob(JB):                       0.0436
# Kurtosis:                       4.193   Cond. No.                     1.18e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+16. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                       df         sum_sq  \
# GDP                                                  1.0  231023.078656
# literacy_rate                                        1.0  104256.413658
# GDP:literacy_rate                                    1.0    5187.607136
# health_exp                                           1.0     144.233484
# GDP:health_exp                                       1.0    4038.750712
# literacy_rate:health_exp                             1.0      87.540457
# GDP:literacy_rate:health_exp                         1.0     745.552087
# pov_headcount                                        1.0     124.675494
# GDP:pov_headcount                                    1.0     599.159964
# literacy_rate:pov_headcount                          1.0       6.971406
# GDP:literacy_rate:pov_headcount                      1.0       7.452836
# health_exp:pov_headcount                             1.0      99.933609
# GDP:health_exp:pov_headcount                         1.0      43.760058
# literacy_rate:health_exp:pov_headcount               1.0      44.680857
# GDP:literacy_rate:health_exp:pov_headcount           1.0       0.008413
# labor_force                                          1.0     525.448796
# GDP:labor_force                                      1.0     136.491383
# literacy_rate:labor_force                            1.0      23.993624
# GDP:literacy_rate:labor_force                        1.0       0.057771
# health_exp:labor_force                               1.0       6.794175
# GDP:health_exp:labor_force                           1.0       0.092080
# literacy_rate:health_exp:labor_force                 1.0       0.003381
# GDP:literacy_rate:health_exp:labor_force             1.0       0.983179
# pov_headcount:labor_force                            1.0       0.877115
# GDP:pov_headcount:labor_force                        1.0       1.209487
# literacy_rate:pov_headcount:labor_force              1.0       0.229984
# GDP:literacy_rate:pov_headcount:labor_force          1.0       0.004529
# health_exp:pov_headcount:labor_force                 1.0     572.930136
# GDP:health_exp:pov_headcount:labor_force             1.0      74.641174
# literacy_rate:health_exp:pov_headcount:labor_force   1.0    3197.067062
# GDP:literacy_rate:health_exp:pov_headcount:labo...   1.0    1005.359414
# Residual                                            34.0   13485.228087
#
#                                                           mean_sq           F  \
# GDP                                                 231023.078656  582.473253
# literacy_rate                                       104256.413658  262.859333
# GDP:literacy_rate                                     5187.607136   13.079396
# health_exp                                             144.233484    0.363653
# GDP:health_exp                                        4038.750712   10.182811
# literacy_rate:health_exp                                87.540457    0.220714
# GDP:literacy_rate:health_exp                           745.552087    1.879744
# pov_headcount                                          124.675494    0.314341
# GDP:pov_headcount                                      599.159964    1.510648
# literacy_rate:pov_headcount                              6.971406    0.017577
# GDP:literacy_rate:pov_headcount                          7.452836    0.018791
# health_exp:pov_headcount                                99.933609    0.251960
# GDP:health_exp:pov_headcount                            43.760058    0.110331
# literacy_rate:health_exp:pov_headcount                  44.680857    0.112653
# GDP:literacy_rate:health_exp:pov_headcount               0.008413    0.000021
# labor_force                                            525.448796    1.324802
# GDP:labor_force                                        136.491383    0.344133
# literacy_rate:labor_force                               23.993624    0.060495
# GDP:literacy_rate:labor_force                            0.057771    0.000146
# health_exp:labor_force                                   6.794175    0.017130
# GDP:health_exp:labor_force                               0.092080    0.000232
# literacy_rate:health_exp:labor_force                     0.003381    0.000009
# GDP:literacy_rate:health_exp:labor_force                 0.983179    0.002479
# pov_headcount:labor_force                                0.877115    0.002211
# GDP:pov_headcount:labor_force                            1.209487    0.003049
# literacy_rate:pov_headcount:labor_force                  0.229984    0.000580
# GDP:literacy_rate:pov_headcount:labor_force              0.004529    0.000011
# health_exp:pov_headcount:labor_force                   572.930136    1.444516
# GDP:health_exp:pov_headcount:labor_force                74.641174    0.188191
# literacy_rate:health_exp:pov_headcount:labor_force    3197.067062    8.060693
# GDP:literacy_rate:health_exp:pov_headcount:labo...    1005.359414    2.534790
# Residual                                               396.624355         NaN
#
#                                                           PR(>F)
# GDP                                                 5.639295e-23
# literacy_rate                                       1.444287e-17
# GDP:literacy_rate                                   9.569662e-04
# health_exp                                          5.504864e-01
# GDP:health_exp                                      3.045504e-03
# literacy_rate:health_exp                            6.414959e-01
# GDP:literacy_rate:health_exp                        1.793459e-01
# pov_headcount                                       5.787045e-01
# GDP:pov_headcount                                   2.274790e-01
# literacy_rate:pov_headcount                         8.953089e-01
# GDP:literacy_rate:pov_headcount                     8.917768e-01
# health_exp:pov_headcount                            6.189334e-01
# GDP:health_exp:pov_headcount                        7.418065e-01
# literacy_rate:health_exp:pov_headcount              7.392063e-01
# GDP:literacy_rate:health_exp:pov_headcount          9.963522e-01
# labor_force                                         2.577625e-01
# GDP:labor_force                                     5.613285e-01
# literacy_rate:labor_force                           8.071947e-01
# GDP:literacy_rate:labor_force                       9.904412e-01
# health_exp:labor_force                              8.966403e-01
# GDP:health_exp:labor_force                          9.879323e-01
# literacy_rate:health_exp:labor_force                9.976874e-01
# GDP:literacy_rate:health_exp:labor_force            9.605825e-01
# pov_headcount:labor_force                           9.627676e-01
# GDP:pov_headcount:labor_force                       9.562850e-01
# literacy_rate:pov_headcount:labor_force             9.809295e-01
# GDP:literacy_rate:pov_headcount:labor_force         9.973235e-01
# health_exp:pov_headcount:labor_force                2.377146e-01
# GDP:health_exp:pov_headcount:labor_force            6.671667e-01
# literacy_rate:health_exp:pov_headcount:labor_force  7.580867e-03
# GDP:literacy_rate:health_exp:pov_headcount:labo...  1.206177e-01
# Residual                                                     NaN

# %% [markdown]
# Since we chose a significance level of 10% we should look at the  P>|t| column. The ratios that less than 10% is significant for our statistical model. These variables are GDP and literacy rate.

# %%
model = ols('mortality_rate ~ GDP	* literacy_rate', data=df).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         mortality_rate   R-squared:                       0.944
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     327.1
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):           2.70e-36
# Time:                        16:43:20   Log-Likelihood:                -267.23
# No. Observations:                  62   AIC:                             542.5
# Df Residuals:                      58   BIC:                             551.0
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           226.4692      6.089     37.191      0.000     214.280     238.658
# GDP                  -0.0303      0.007     -4.076      0.000      -0.045      -0.015
# literacy_rate        -1.8930      0.120    -15.758      0.000      -2.133      -1.653
# GDP:literacy_rate     0.0003   7.52e-05      3.867      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                        0.604   Durbin-Watson:                   0.391
# Prob(Omnibus):                  0.739   Jarque-Bera (JB):                0.579
# Skew:                           0.222   Prob(JB):                        0.749
# Kurtosis:                       2.834   Cond. No.                     1.30e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                      df         sum_sq        mean_sq           F  \
# GDP                 1.0  231023.078656  231023.078656  665.834329
# literacy_rate       1.0  104256.413658  104256.413658  300.478634
# GDP:literacy_rate   1.0    5187.607136    5187.607136   14.951263
# Residual           58.0   20124.132969     346.967810         NaN
#
#                          PR(>F)
# GDP                1.760914e-33
# literacy_rate      1.303975e-24
# GDP:literacy_rate  2.814121e-04
# Residual                    NaN

# %% [markdown]
# As we see with these two variables we found a 94.4% R-squared value that is inside of our chosen interval. I think that is the best we can chose to explain Chield Mortality Rate.

# %% [markdown]
# # Question 2
#
# For this question use Yahoo's Finance API for the following tickers:
#
# * Gold futures (GC=F)
# * Silver futures (SI=F)
# * Copper futures (HG=F)
# * Platinum futures (PL=F)
#
# 1. Write the best linear regression model that explains gold futures closing prices in terms of opening prices of gold, silver, copper, and platinum futures.
# 2. Repeat the same for silver, copper and platinum prices.
# 3. Compare the models you obtained in Steps 1 and 2. Which model is better? How do you decide? Explain.

# %%
from yahoo_fin.stock_info import get_data;

# %% [markdown]
# I import the yahoo's get_data method to pull data from the API. It takes the 5 arguments which is very helpful.

# %%
def pull_data_yahoo(ticker):
  pull_data_yahoo = get_data(ticker, start_date =" 09/07/1999", end_date = "10/07/2022", index_as_date = True, interval = '1d').fillna(0)
  return pull_data_yahoo

# %% [markdown]
# I also build a new function to pull data from yahoo finance API. This is done all by me. Not like the first one.

# %%
gc_f = pull_data_yahoo("GC=F").ffill().dropna()
sil_f = pull_data_yahoo("SI=F").ffill().dropna()
hg_f = pull_data_yahoo("HG=F").ffill().dropna()
plat_f = pull_data_yahoo("PL=F").ffill().dropna()

# %% [markdown]
# I pull the data and firstly tried to use "dropna()" method to get rid of NA data. However it did not worked well so I decided to use "fillna(0)" and "ffill()" -AKA forward fill it takes the last value and put the rest the same value untill it sees a new value. In order not the block these unknown data for my model

# %%
new_df= pd.DataFrame()
new_df["gold_close"] = gc_f["close"]
new_df["gold_open"] =gc_f["open"]
new_df["silver_open"] =sil_f["open"]
new_df["silver_close"] =sil_f["close"]
new_df["copper_open"] =hg_f["open"]
new_df["copper_close"] =hg_f["close"]
new_df["platinum_open"] =plat_f["open"]
new_df["platinum_close"] =plat_f["close"]
new_df
# Out:
#              gold_close    gold_open  silver_open  silver_close  copper_open  \
# 2000-08-30   273.899994   273.899994     4.950000      4.930000       0.8790
# 2000-08-31   278.299988   274.799988     4.920000      5.003000       0.8850
# 2000-09-01   277.000000   277.000000     5.035000      5.004000       0.8780
# 2000-09-04     0.000000     0.000000     0.000000      0.000000       0.0000
# 2000-09-05   275.799988   275.799988     4.990000      4.998000       0.8960
# ...                 ...          ...          ...           ...          ...
# 2022-09-30  1662.400024  1661.699951    18.844999     18.959999       3.4440
# 2022-10-03  1692.900024  1667.199951    20.170000     20.518999       3.4000
# 2022-10-04  1721.099976  1701.199951    20.820000     21.037001       3.4640
# 2022-10-05  1711.400024  1724.099976    20.795000     20.479000       3.5290
# 2022-10-06  1711.699951  1721.000000    20.610001     20.594999       3.4925
#
#             copper_close  platinum_open  platinum_close
# 2000-08-30        0.8850     593.900024      591.400024
# 2000-08-31        0.8850     589.000000      586.700012
# 2000-09-01        0.8890     588.000000      595.299988
# 2000-09-04        0.0000       0.000000        0.000000
# 2000-09-05        0.9060     602.000000      601.299988
# ...                  ...            ...             ...
# 2022-09-30        3.4420     869.000000      870.000000
# 2022-10-03        3.4580     895.000000      911.299988
# 2022-10-04        3.5180     911.299988      943.700012
# 2022-10-05        3.5325     946.400024      924.599976
# 2022-10-06        3.4750     931.700012      931.700012
#
# [5631 rows x 8 columns]

# %% [markdown]
# I created a new DataFrame to put the needed values for the model.

# %%
model = ols('gold_close ~ gold_open *silver_open*copper_open*platinum_open', data=new_df).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gold_close   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.532e+05
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        18:55:17   Log-Likelihood:                -21457.
# No. Observations:                5631   AIC:                         4.295e+04
# Df Residuals:                    5615   BIC:                         4.305e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                           0.4515      1.194      0.378      0.705      -1.889       2.792
# gold_open                                           0.9969      0.009    117.052      0.000       0.980       1.014
# silver_open                                        -0.2738      0.693     -0.395      0.693      -1.633       1.085
# gold_open:silver_open                               0.0008      0.000      1.997      0.046    1.49e-05       0.002
# copper_open                                         0.3841      1.346      0.285      0.775      -2.254       3.022
# gold_open:copper_open                            1.815e-05      0.003      0.007      0.994      -0.005       0.005
# silver_open:copper_open                             0.0524      0.188      0.278      0.781      -0.317       0.421
# gold_open:silver_open:copper_open                  -0.0002    9.9e-05     -1.956      0.050      -0.000    4.02e-07
# platinum_open                                      -0.0010      0.003     -0.368      0.713      -0.007       0.004
# gold_open:platinum_open                         -2.427e-06   8.93e-06     -0.272      0.786   -1.99e-05    1.51e-05
# silver_open:platinum_open                           0.0011      0.001      1.362      0.173      -0.000       0.003
# gold_open:silver_open:platinum_open             -1.103e-06   3.99e-07     -2.765      0.006   -1.88e-06   -3.21e-07
# copper_open:platinum_open                          -0.0018      0.001     -1.304      0.192      -0.005       0.001
# gold_open:copper_open:platinum_open              2.692e-06   2.58e-06      1.044      0.297   -2.36e-06    7.75e-06
# silver_open:copper_open:platinum_open              -0.0002      0.000     -0.998      0.318      -0.001       0.000
# gold_open:silver_open:copper_open:platinum_open  2.079e-07   9.28e-08      2.240      0.025    2.59e-08     3.9e-07
# ==============================================================================
# Omnibus:                     1660.611   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36172.093
# Skew:                          -0.886   Prob(JB):                         0.00
# Kurtosis:                      15.289   Cond. No.                     1.41e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                      df        sum_sq  \
# gold_open                                           1.0  1.533650e+09
# silver_open                                         1.0  6.045732e-02
# gold_open:silver_open                               1.0  3.906405e+02
# copper_open                                         1.0  1.257966e-01
# gold_open:copper_open                               1.0  1.061514e+03
# silver_open:copper_open                             1.0  1.608800e+02
# gold_open:silver_open:copper_open                   1.0  2.630560e+01
# platinum_open                                       1.0  8.533687e-01
# gold_open:platinum_open                             1.0  2.547339e+01
# silver_open:platinum_open                           1.0  1.506296e+01
# gold_open:silver_open:platinum_open                 1.0  9.180710e+01
# copper_open:platinum_open                           1.0  5.605327e+01
# gold_open:copper_open:platinum_open                 1.0  6.827320e+02
# silver_open:copper_open:platinum_open               1.0  5.816575e+01
# gold_open:silver_open:copper_open:platinum_open     1.0  6.010625e+02
# Residual                                         5615.0  6.728459e+05
#
#                                                       mean_sq             F  \
# gold_open                                        1.533650e+09  1.279854e+07
# silver_open                                      6.045732e-02  5.045254e-04
# gold_open:silver_open                            3.906405e+02  3.259954e+00
# copper_open                                      1.257966e-01  1.049792e-03
# gold_open:copper_open                            1.061514e+03  8.858490e+00
# silver_open:copper_open                          1.608800e+02  1.342568e+00
# gold_open:silver_open:copper_open                2.630560e+01  2.195242e-01
# platinum_open                                    8.533687e-01  7.121490e-03
# gold_open:platinum_open                          2.547339e+01  2.125792e-01
# silver_open:platinum_open                        1.506296e+01  1.257027e-01
# gold_open:silver_open:platinum_open              9.180710e+01  7.661441e-01
# copper_open:platinum_open                        5.605327e+01  4.677730e-01
# gold_open:copper_open:platinum_open              6.827320e+02  5.697501e+00
# silver_open:copper_open:platinum_open            5.816575e+01  4.854019e-01
# gold_open:silver_open:copper_open:platinum_open  6.010625e+02  5.015957e+00
# Residual                                         1.198301e+02           NaN
#
#                                                    PR(>F)
# gold_open                                        0.000000
# silver_open                                      0.982081
# gold_open:silver_open                            0.071045
# copper_open                                      0.974154
# gold_open:copper_open                            0.002930
# silver_open:copper_open                          0.246631
# gold_open:silver_open:copper_open                0.639421
# platinum_open                                    0.932750
# gold_open:platinum_open                          0.644771
# silver_open:platinum_open                        0.722943
# gold_open:silver_open:platinum_open              0.381450
# copper_open:platinum_open                        0.494042
# gold_open:copper_open:platinum_open              0.017022
# silver_open:copper_open:platinum_open            0.486014
# gold_open:silver_open:copper_open:platinum_open  0.025154
# Residual                                              NaN

# %% [markdown]
# OLS results are significantly accurate. R-squarred value is one. What can be better than that?. P>|t| also says that **gold_open** interaction of **gold_open and silver_open / gold_open, silver_open and copper_open/ gold_open, silver_open and platinum_open/ gold_open, silver_open, copper_open, platinum_open** explains the gold_close price well.

# %%
X = new_df[['silver_open','copper_open', 'gold_open','platinum_open']]
XX = sm.add_constant(X)
Y = new_df['gold_close']
model = sm.OLS(Y,XX)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             gold_close   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.191e+06
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        18:56:01   Log-Likelihood:                -21470.
# No. Observations:                5631   AIC:                         4.295e+04
# Df Residuals:                    5626   BIC:                         4.298e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0862      0.395      0.218      0.827      -0.688       0.860
# silver_open      -0.0283      0.045     -0.626      0.531      -0.117       0.060
# copper_open       0.2174      0.248      0.878      0.380      -0.268       0.703
# gold_open         0.9995      0.001   1627.104      0.000       0.998       1.001
# platinum_open     0.0002      0.000      0.527      0.598      -0.001       0.001
# ==============================================================================
# Omnibus:                     1727.933   Durbin-Watson:                   2.045
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            37465.706
# Skew:                          -0.944   Prob(JB):                         0.00
# Kurtosis:                      15.495   Cond. No.                     4.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# Also tried another way the for model. It also gave me a good solution. I can say that just from R-squared value. P>|t| colums says us only **gold_open** explains data well. Other variables' intervals contains zero. This means they are not a good choice.

# %%
model = ols('silver_close ~ gold_open *silver_open*copper_open*platinum_open', data=new_df).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           silver_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.031e+05
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        09:59:24   Log-Likelihood:                -1223.4
# No. Observations:                5631   AIC:                             2479.
# Df Residuals:                    5615   BIC:                             2585.
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          -0.0076      0.033     -0.231      0.817      -0.072       0.057
# gold_open                                          -0.0002      0.000     -0.739      0.460      -0.001       0.000
# silver_open                                         1.0071      0.019     52.813      0.000       0.970       1.044
# gold_open:silver_open                            1.259e-05    1.1e-05      1.139      0.255   -9.07e-06    3.42e-05
# copper_open                                         0.0121      0.037      0.328      0.743      -0.060       0.085
# gold_open:copper_open                            3.117e-06   7.18e-05      0.043      0.965      -0.000       0.000
# silver_open:copper_open                         -3.076e-05      0.005     -0.006      0.995      -0.010       0.010
# gold_open:silver_open:copper_open               -4.453e-06   2.72e-06     -1.636      0.102   -9.79e-06    8.84e-07
# platinum_open                                    9.033e-05    7.7e-05      1.173      0.241   -6.07e-05       0.000
# gold_open:platinum_open                          2.782e-07   2.46e-07      1.133      0.257   -2.03e-07    7.59e-07
# silver_open:platinum_open                        -2.67e-05   2.22e-05     -1.205      0.228   -7.01e-05    1.67e-05
# gold_open:silver_open:platinum_open             -9.365e-09    1.1e-08     -0.854      0.393   -3.09e-08    1.21e-08
# copper_open:platinum_open                       -5.606e-05   3.85e-05     -1.457      0.145      -0.000    1.94e-05
# gold_open:copper_open:platinum_open              1.893e-08   7.09e-08      0.267      0.790    -1.2e-07    1.58e-07
# silver_open:copper_open:platinum_open            5.271e-06   5.15e-06      1.023      0.306   -4.83e-06    1.54e-05
# gold_open:silver_open:copper_open:platinum_open  1.853e-09   2.55e-09      0.726      0.468   -3.15e-09    6.86e-09
# ==============================================================================
# Omnibus:                     4069.921   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           533910.327
# Skew:                          -2.602   Prob(JB):                         0.00
# Kurtosis:                      50.418   Cond. No.                     1.41e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                      df         sum_sq  \
# gold_open                                           1.0  320629.779163
# silver_open                                         1.0   91614.165480
# gold_open:silver_open                               1.0       0.441197
# copper_open                                         1.0       0.041453
# gold_open:copper_open                               1.0       0.480401
# silver_open:copper_open                             1.0       0.533007
# gold_open:silver_open:copper_open                   1.0       0.014202
# platinum_open                                       1.0       0.348728
# gold_open:platinum_open                             1.0       0.843397
# silver_open:platinum_open                           1.0       0.174593
# gold_open:silver_open:platinum_open                 1.0       0.059705
# copper_open:platinum_open                           1.0       0.359076
# gold_open:copper_open:platinum_open                 1.0       0.989135
# silver_open:copper_open:platinum_open               1.0       0.381593
# gold_open:silver_open:copper_open:platinum_open     1.0       0.047761
# Residual                                         5615.0     509.130689
#
#                                                        mean_sq             F  \
# gold_open                                        320629.779163  3.536098e+06
# silver_open                                       91614.165480  1.010376e+06
# gold_open:silver_open                                 0.441197  4.865782e+00
# copper_open                                           0.041453  4.571657e-01
# gold_open:copper_open                                 0.480401  5.298150e+00
# silver_open:copper_open                               0.533007  5.878326e+00
# gold_open:silver_open:copper_open                     0.014202  1.566317e-01
# platinum_open                                         0.348728  3.845987e+00
# gold_open:platinum_open                               0.843397  9.301485e+00
# silver_open:platinum_open                             0.174593  1.925516e+00
# gold_open:silver_open:platinum_open                   0.059705  6.584668e-01
# copper_open:platinum_open                             0.359076  3.960112e+00
# gold_open:copper_open:platinum_open                   0.989135  1.090877e+01
# silver_open:copper_open:platinum_open                 0.381593  4.208439e+00
# gold_open:silver_open:copper_open:platinum_open       0.047761  5.267412e-01
# Residual                                              0.090673           NaN
#
#                                                    PR(>F)
# gold_open                                        0.000000
# silver_open                                      0.000000
# gold_open:silver_open                            0.027435
# copper_open                                      0.498979
# gold_open:copper_open                            0.021385
# silver_open:copper_open                          0.015360
# gold_open:silver_open:copper_open                0.692292
# platinum_open                                    0.049915
# gold_open:platinum_open                          0.002300
# silver_open:platinum_open                        0.165305
# gold_open:silver_open:platinum_open              0.417136
# copper_open:platinum_open                        0.046639
# gold_open:copper_open:platinum_open              0.000963
# silver_open:copper_open:platinum_open            0.040270
# gold_open:silver_open:copper_open:platinum_open  0.468010
# Residual                                              NaN

# %% [markdown]
# In the OLS regression results it can be seen that **silver_open** and a interaction of **gold_open, silver_open and copper_open** gives a good data set to explain silver close price.

# %%
X = new_df[['silver_open','copper_open', 'gold_open','platinum_open']]
XX = sm.add_constant(X)
Y = new_df['silver_close']
model = sm.OLS(Y,XX)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           silver_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.130e+06
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        19:02:30   Log-Likelihood:                -1245.1
# No. Observations:                5631   AIC:                             2500.
# Df Residuals:                    5626   BIC:                             2533.
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0036      0.011     -0.335      0.737      -0.025       0.018
# silver_open       0.9951      0.001    797.532      0.000       0.993       0.998
# copper_open       0.0113      0.007      1.658      0.097      -0.002       0.025
# gold_open      1.986e-05   1.69e-05      1.174      0.241   -1.33e-05     5.3e-05
# platinum_open  2.532e-05   1.07e-05      2.370      0.018    4.38e-06    4.63e-05
# ==============================================================================
# Omnibus:                     4220.810   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           593138.340
# Skew:                          -2.747   Prob(JB):                         0.00
# Kurtosis:                      52.978   Cond. No.                     4.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# p-values of silver_open and copper_open seem good for the model but the copper_open's interval contains zero. so only silver_open may explain this model.

# %%
model = ols('copper_close ~ gold_open *silver_open*copper_open*platinum_open', data=new_df).fit()
print(model.summary())
sm.stats.anova_lm(model)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           copper_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 3.182e+05
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        10:08:26   Log-Likelihood:                 10303.
# No. Observations:                5631   AIC:                        -2.057e+04
# Df Residuals:                    5615   BIC:                        -2.047e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ===================================================================================================================
#                                                       coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# Intercept                                          -0.0009      0.004     -0.217      0.828      -0.009       0.007
# gold_open                                       -2.725e-05   3.03e-05     -0.901      0.368   -8.66e-05    3.21e-05
# silver_open                                         0.0026      0.002      1.052      0.293      -0.002       0.007
# gold_open:silver_open                            6.107e-07   1.43e-06      0.428      0.669   -2.19e-06    3.41e-06
# copper_open                                         1.0012      0.005    209.448      0.000       0.992       1.011
# gold_open:copper_open                            1.859e-06   9.27e-06      0.201      0.841   -1.63e-05       2e-05
# silver_open:copper_open                            -0.0009      0.001     -1.315      0.188      -0.002       0.000
# gold_open:silver_open:copper_open                1.702e-07   3.52e-07      0.484      0.628   -5.19e-07    8.59e-07
# platinum_open                                   -7.051e-06   9.95e-06     -0.709      0.478   -2.66e-05    1.25e-05
# gold_open:platinum_open                          9.261e-09   3.17e-08      0.292      0.770   -5.29e-08    7.14e-08
# silver_open:platinum_open                        3.581e-07   2.86e-06      0.125      0.900   -5.25e-06    5.97e-06
# gold_open:silver_open:platinum_open             -1.092e-09   1.42e-09     -0.771      0.441   -3.87e-09    1.69e-09
# copper_open:platinum_open                        2.764e-06   4.97e-06      0.556      0.578   -6.98e-06    1.25e-05
# gold_open:copper_open:platinum_open              2.419e-10   9.16e-09      0.026      0.979   -1.77e-08    1.82e-08
# silver_open:copper_open:platinum_open             1.43e-08   6.65e-07      0.022      0.983   -1.29e-06    1.32e-06
# gold_open:silver_open:copper_open:platinum_open  7.628e-11    3.3e-10      0.231      0.817    -5.7e-10    7.23e-10
# ==============================================================================
# Omnibus:                      899.443   Durbin-Watson:                   2.152
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14454.173
# Skew:                           0.220   Prob(JB):                         0.00
# Kurtosis:                      10.837   Cond. No.                     1.41e+09
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.41e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                                                      df       sum_sq  \
# gold_open                                           1.0  4662.980007
# silver_open                                         1.0   595.297128
# gold_open:silver_open                               1.0   506.426920
# copper_open                                         1.0  1452.475361
# gold_open:copper_open                               1.0     0.000012
# silver_open:copper_open                             1.0     0.009536
# gold_open:silver_open:copper_open                   1.0     0.000001
# platinum_open                                       1.0     0.009259
# gold_open:platinum_open                             1.0     0.000854
# silver_open:platinum_open                           1.0     0.000058
# gold_open:silver_open:platinum_open                 1.0     0.009564
# copper_open:platinum_open                           1.0     0.003996
# gold_open:copper_open:platinum_open                 1.0     0.000183
# silver_open:copper_open:platinum_open               1.0     0.000088
# gold_open:silver_open:copper_open:platinum_open     1.0     0.000081
# Residual                                         5615.0     8.489946
#
#                                                      mean_sq             F  \
# gold_open                                        4662.980007  3.083958e+06
# silver_open                                       595.297128  3.937120e+05
# gold_open:silver_open                             506.426920  3.349358e+05
# copper_open                                      1452.475361  9.606244e+05
# gold_open:copper_open                               0.000012  7.702267e-03
# silver_open:copper_open                             0.009536  6.306550e+00
# gold_open:silver_open:copper_open                   0.000001  8.616319e-04
# platinum_open                                       0.009259  6.123500e+00
# gold_open:platinum_open                             0.000854  5.647872e-01
# silver_open:platinum_open                           0.000058  3.804791e-02
# gold_open:silver_open:platinum_open                 0.009564  6.325611e+00
# copper_open:platinum_open                           0.003996  2.642641e+00
# gold_open:copper_open:platinum_open                 0.000183  1.207017e-01
# silver_open:copper_open:platinum_open               0.000088  5.799910e-02
# gold_open:silver_open:copper_open:platinum_open     0.000081  5.351287e-02
# Residual                                            0.001512           NaN
#
#                                                    PR(>F)
# gold_open                                        0.000000
# silver_open                                      0.000000
# gold_open:silver_open                            0.000000
# copper_open                                      0.000000
# gold_open:copper_open                            0.930069
# silver_open:copper_open                          0.012057
# gold_open:silver_open:copper_open                0.976584
# platinum_open                                    0.013369
# gold_open:platinum_open                          0.452369
# silver_open:platinum_open                        0.845354
# gold_open:silver_open:platinum_open              0.011928
# copper_open:platinum_open                        0.104087
# gold_open:copper_open:platinum_open              0.728288
# silver_open:copper_open:platinum_open            0.809696
# gold_open:silver_open:copper_open:platinum_open  0.817068
# Residual                                              NaN

# %% [markdown]
# In the anova table we can say from PR(>F) column -our interal is still 90%- interaction of **gold_open, silver_open and copper_open** and **gold_open and copper_open** are higher than our value. That means that we can chose these interactions to explain **copper_close** price

# %%
X = new_df[['silver_open','copper_open', 'gold_open','platinum_open']]
XX = sm.add_constant(X)
Y = new_df['copper_close']
model = sm.OLS(Y,XX)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           copper_close   R-squared:                       0.999
# Model:                            OLS   Adj. R-squared:                  0.999
# Method:                 Least Squares   F-statistic:                 1.192e+06
# Date:                Mon, 07 Nov 2022   Prob (F-statistic):               0.00
# Time:                        19:02:31   Log-Likelihood:                 10294.
# No. Observations:                5631   AIC:                        -2.058e+04
# Df Residuals:                    5626   BIC:                        -2.054e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0011      0.001      0.768      0.443      -0.002       0.004
# silver_open      -0.0003      0.000     -1.909      0.056      -0.001    8.27e-06
# copper_open       0.9995      0.001   1137.400      0.000       0.998       1.001
# gold_open      2.302e-06   2.18e-06      1.056      0.291   -1.97e-06    6.58e-06
# platinum_open   3.64e-06   1.38e-06      2.645      0.008    9.42e-07    6.34e-06
# ==============================================================================
# Omnibus:                      907.394   Durbin-Watson:                   2.148
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14657.249
# Skew:                           0.230   Prob(JB):                         0.00
# Kurtosis:                      10.890   Cond. No.                     4.38e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.38e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# As we all see in the all model that we try to explain close value of the meterials all of the above are really accurate to explain each other.

# %% [markdown]
# # Question 3
#
# 1. Write a function that takes a ticker symbol and returns a pandas dataframe that for each day puts a 1 when the closing price is higher than the opening price, a 0 when the closing price is lower than the opening price.
# 2. Write the best logistic regression that predicts the time series you obtain from Step 1 for gold futures against the opening prices of gold, silver, copper, and platinum prices.
# 3. Repeat the same for silver, copper, and platinum prices.
# 4. Compare the models you obtained from Steps 2 and 3. Decide which is the best model, and explain your reasoning.
# 5. Does any of the models provide a good fit? Explain.

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from zipfile import ZipFile
from io import BytesIO
from urllib.request import urlopen
from collections import Counter
from sklearn.metrics import confusion_matrix

from statsmodels.formula.api import logit
from statsmodels.api import Logit

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeRegressor

# %%
def open_close(ticker):
  df_open_close = get_data(ticker, start_date =" 09/07/2022", end_date = "10/07/2022", index_as_date = True, interval = '1d').fillna(0)
  df_open_close["open_close"] = df_open_close["open"]
  for index in df_open_close.index:
    if df_open_close.loc[index]["open"] >= df_open_close.loc[index]["close"]:
        df_open_close["open_close"][index] = 0
    elif df_open_close.loc[index]["open"] < df_open_close.loc[index]["close"]:
        df_open_close["open_close"][index] = 1
  return df_open_close.dropna()

# %%
df_gold= open_close('GC=F') 
df_silv = open_close("SI=F") 
df_coop= open_close("HG=F") 
df_plat = open_close("PL=F")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
def logistic_reg(data):
  model = logit('open_close ~ high + low + open + volume', data=data).fit()
  return model.summary()

# %%
logistic_reg(df_gold)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.409103
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             open_close   No. Observations:                   22
# Model:                          Logit   Df Residuals:                       17
# Method:                           MLE   Df Model:                            4
# Date:                Mon, 07 Nov 2022   Pseudo R-squ.:                  0.4062
# Time:                        19:38:00   Log-Likelihood:                -9.0003
# converged:                       True   LL-Null:                       -15.158
# Covariance Type:            nonrobust   LLR p-value:                   0.01515
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -19.0302     38.473     -0.495      0.621     -94.435      56.375
# high           0.2255      0.125      1.803      0.071      -0.020       0.471
# low            0.0982      0.099      0.997      0.319      -0.095       0.291
# open          -0.3132      0.159     -1.969      0.049      -0.625      -0.001
# volume         0.0003      0.000      0.720      0.472      -0.001       0.001
# ==============================================================================
# """

# %%
logistic_reg(df_coop)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.273219
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             open_close   No. Observations:                   22
# Model:                          Logit   Df Residuals:                       17
# Method:                           MLE   Df Model:                            4
# Date:                Mon, 07 Nov 2022   Pseudo R-squ.:                  0.6035
# Time:                        19:38:04   Log-Likelihood:                -6.0108
# converged:                       True   LL-Null:                       -15.158
# Covariance Type:            nonrobust   LLR p-value:                  0.001081
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -8.5613     30.750     -0.278      0.781     -68.831      51.708
# high          62.1077     39.298      1.580      0.114     -14.915     139.131
# low          113.6448     68.879      1.650      0.099     -21.355     248.644
# open        -173.8907     94.613     -1.838      0.066    -359.329      11.547
# volume         0.0075      0.007      1.003      0.316      -0.007       0.022
# ==============================================================================
# """

# %% [markdown]
# High and low prices are significant. Other ones are not because of the p_values

# %% [markdown]
# Because of there are some rows that has the same value in different colums the variable that I have chosen in my "logistic_reg" function I decide to use other variables in the code below.

# %%
model = logit('open_close ~  open + volume', data=df_silv).fit()
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.603329
#          Iterations 6
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             open_close   No. Observations:                   22
# Model:                          Logit   Df Residuals:                       19
# Method:                           MLE   Df Model:                            2
# Date:                Mon, 07 Nov 2022   Pseudo R-squ.:                  0.1296
# Time:                        19:39:39   Log-Likelihood:                -13.273
# converged:                       True   LL-Null:                       -15.249
# Covariance Type:            nonrobust   LLR p-value:                    0.1386
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.9923     11.525      0.346      0.729     -18.596      26.581
# open          -0.2647      0.596     -0.444      0.657      -1.433       0.903
# volume         0.0143      0.009      1.636      0.102      -0.003       0.031
# ==============================================================================
# """

# %% [markdown]
# # Question 4
#
# For this question use the following [data](https://archive.ics.uci.edu/ml/datasets/credit+approval):

# %%
credit = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/credit-screening/crx.data', header=None)

fn = {'+': 1, '-': 0}

X = credit.replace('?',0).iloc[:,[1,2,7,10,14]]
y = credit.iloc[:,15].map(lambda x: fn.get(x,0))

# %% [markdown]
# 1. Split the data into training and test set.
# 2. Write different logistic regression models predicting y against X.
# 3. Construct [confusion matrices](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html) on the test data set for these different models.
# 4. Analyze these models. Explain which model is the best model you have found.
# 5. Repeat Steps 1-4 several times. Does your best model stay as the best model? What should be the correct protocol to decide on the best model explaining the data?

# %%
X
# Out:
#         1       2     7   10   14
# 0    30.83   0.000  1.25   1    0
# 1    58.67   4.460  3.04   6  560
# 2    24.50   0.500  1.50   0  824
# 3    27.83   1.540  3.75   5    3
# 4    20.17   5.625  1.71   0    0
# ..     ...     ...   ...  ..  ...
# 685  21.08  10.085  1.25   0    0
# 686  22.67   0.750  2.00   2  394
# 687  25.25  13.500  2.00   1    1
# 688  17.92   0.205  0.04   0  750
# 689  35.00   3.375  8.29   0    0
#
# [690 rows x 5 columns]

# %%
X["y"] = y

# %%
X =X.rename(columns ={1:"one", 2:"two", 7:"seven", 10:"ten", 14:"forteen"})
X

# %%
model = logit('y ~ one + two + seven + ten + forteen', data=X).fit()
model.summary()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: inf
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-73-0595ac32c6b5> in <module>
# ----> 1 model = logit('y ~ one + two + seven + ten ', data=X).fit()
#       2 model.summary()
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1978                               disp=disp,
#    1979                               callback=callback,
# -> 1980                               **kwargs)
#    1981
#    1982         discretefit = LogitResults(self, bnryfit)
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/discrete/discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     231                              disp=disp,
#     232                              callback=callback,
# --> 233                              **kwargs)
#     234
#     235         return mlefit  # It is up to subclasses to wrap results
#
# /usr/local/lib/python3.7/dist-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     532             Hinv = cov_params_func(self, xopt, retvals)
#     533         elif method == 'newton' and full_output:
# --> 534             Hinv = np.linalg.inv(-retvals['Hessian']) / nobs
#     535         elif not skip_hessian:
#     536             H = -1 * self.hessian(xopt)
#
# <__array_function__ internals> in inv(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# /usr/local/lib/python3.7/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
